# %% [markdown]
# # Lab 1 - Interpretable by Design
# Clean version with minimal structure and TODOs.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %% [markdown]
# ## TODO dataset and preprocessing
# 1. Load `diabetes.csv`.
# 2. Split numeric and categorical features.
# 3. Apply encoding/scaling and create a train/test split.

# %%
# TODO: data loading and preprocessing

# %% [markdown]
# ## TODO interpretable models
# 1. Train a Decision Tree and visualize it.
# 2. Train Logistic Regression and KNN (with optional GridSearchCV).
# 3. Compare metrics and confusion matrix.

# %%
# TODO: model training and evaluation

# %% [markdown]
# ## TODO final analysis
# 1. Comment on the trade-off between accuracy and interpretability.
# 2. Justify which model to choose in a real-world context.
